# %% [markdown]
# <a href="https://colab.research.google.com/github/ceumartins/estudo-machine-learning/blob/main/Exemplo1_MatplotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
from sklearn.datasets import make_regression
x, y = make_regression(n_samples=200, n_features=1, noise=80)
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.show()
